# %% [markdown]
# ## Решение задачи кластеризации (метод k-means)
# ![image.png](attachment:02cb7d47-3b64-4ec5-9f2d-fa065a3dbe3e.png)

# %% [markdown]
# ## Решение задачи кластеризации (метод Hierarchical Clustering)
# ![image.png](attachment:b1bb4f75-4c90-4a50-9d1a-5e7dce8146ca.png)

# %% [markdown]
# ## Решение задачи классификации через Orange
# dataset StudentsPerformance.csv был взят с сайта https://www.kaggle.com. В качестве задачи классификации я буду определять по студенческим оценкам пол студента. Методы анализа данных, которые я использовал: логическая регрессия и дерево решений.
# #### Цепочка виджетов Orange
# ![image.png](attachment:84f55553-9e19-44ff-9d1e-783d32801f12.png)
#
# #### Результат (обучающие данные):
# ![image.png](attachment:505f883c-b9a9-496e-a8e5-08bf3153579b.png)
#
# #### Результат (тестовые данные):
# ![image.png](attachment:c04cc213-b8bf-4599-83e9-fdc852c7ef8a.png)
